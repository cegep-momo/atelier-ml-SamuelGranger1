# %%
import pandas as pnd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras

tf.config.set_visible_devices([], 'GPU')

#Définition de la longueur et de la largeur de l'image
LONGUEUR_IMAGE = 28
LARGEUR_IMAGE = 28

#Chargement des images
observations_entrainement = pnd.read_csv('datas/fashion-mnist_train.csv')

#On exclut la première colonne (les labels) pour constituer un tableau de pixels
X = np.array(observations_entrainement.iloc[:, 1:])

premiereImage = X[0]
premiereImage = premiereImage.reshape([LONGUEUR_IMAGE,LARGEUR_IMAGE])
plt.imshow(premiereImage)
plt.show()

#On crée des catégories à l'aide du module Keras
y = keras.utils.to_categorical(np.array(observations_entrainement.iloc[:,0]))
#Répartition des données d'entrainement en données d'apprentissage et données de validation
#80% de donnée d'apprentissage et 20% de donnée de validation
X_apprentissage, X_validation, y_apprentissage, y_validation = train_test_split(X, y, test_size=0.2, random_state=13)

# On redimensionne les images au format 28*28 et on réalise un scaling sur les données des pixels
X_apprentissage = X_apprentissage.reshape(X_apprentissage.shape[0], 
                                          LARGEUR_IMAGE, 
                                          LONGUEUR_IMAGE, 1)
X_apprentissage = X_apprentissage.astype('float32')
X_apprentissage /= 255

X_validation = X_validation.reshape(X_validation.shape[0], 
                                    LARGEUR_IMAGE, 
                                    LONGUEUR_IMAGE, 1)
X_validation = X_validation.astype('float32')
X_validation /= 255

#Preparation des données de tests
observations_test = pnd.read_csv('datas/fashion-mnist_test.csv')
X_test = np.array(observations_test.iloc[:, 1:])
y_test = tf.keras.utils.to_categorical(np.array(observations_test.iloc[:, 0]))
X_test = X_test.reshape(X_test.shape[0], 
                        LARGEUR_IMAGE, 
                        LONGUEUR_IMAGE, 1)
X_test = X_test.astype('float32')
X_test /= 255

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D

# On spécifie les dimensions de l'image d'entrée
dimentionImage = (LARGEUR_IMAGE, LONGUEUR_IMAGE, 1)

# On crée le réseau de neurones couche par couche
reseauNeurone1Convolution = Sequential()

# Ajout de la couche d'entrée
reseauNeurone1Convolution.add(Input(shape=dimentionImage))

#1- Ajout de la couche de convolution comportant
# 32 filtres de de taille 3x3 (Kernel) parcourant l'image
# Une fonction d'activation de type ReLU (Rectified Linear Activation)
# Une image d'entrée de 28px * 28 px 
reseauNeurone1Convolution.add(Conv2D(32, 
                                     kernel_size=(3, 3), 
                                     activation='relu'))

#2- Définition de la fonction de pooling avec une fenêtre de 2px sur 2 px
reseauNeurone1Convolution.add(MaxPooling2D(pool_size=(2, 2)))

#3- Ajout d'une fonction d'ignorance
reseauNeurone1Convolution.add(Dropout(0.2))

#5 - On transforme en une seule ligne
reseauNeurone1Convolution.add(Flatten())

#6 - Ajout d'un réseau de neurones composé de 128 neurones avec 
# une fonction d'activation de type ReLU
reseauNeurone1Convolution.add(Dense(128, activation='relu'))

#7 - Ajout d'un réseau de neurones composé de 10 neurones avec une 
# fonction d'activation de type softmax
reseauNeurone1Convolution.add(Dense(10, activation='softmax'))

reseauNeurone1Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

historique_apprentissage = reseauNeurone1Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))


evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])


plt.plot(historique_apprentissage.history['accuracy'])
plt.plot(historique_apprentissage.history['val_accuracy'])
plt.title('Précision du modèle')
plt.ylabel('Précision')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()
# Plot training & validation loss values
plt.plot(historique_apprentissage.history['loss'])
plt.plot(historique_apprentissage.history['val_loss'])
plt.title('Erreur')
plt.ylabel('Erreur')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()

from tensorflow.keras.preprocessing.image import ImageDataGenerator

generateur_images = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    shear_range=0.3,
    height_shift_range=0.08,
    zoom_range=0.08)


nouvelles_images_apprentissage = generateur_images.flow(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256)

nouvelles_images_validation = generateur_images.flow(
    X_validation, 
    y_validation,
    batch_size=256)

historique_apprentissage = reseauNeurone1Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])

#Sauvegarde du modèle
# Serialisation du modèle 
model_json = reseauNeurone1Convolution.to_json() 
with open("modele/modele.json", "w") as json_file:
    json_file.write(model_json)
    
# Serialisation des poids
reseauNeurone1Convolution.save_weights("modele/modele.weights.h5")
print("Modèle sauvegardé !")

from keras.layers import BatchNormalization

reseauNeurones4Convolution = Sequential()

reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=dimentionImage))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Flatten())
reseauNeurones4Convolution.add(Dense(512, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(128, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(10, activation='softmax'))

reseauNeurones4Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

historique_apprentissage = reseauNeurones4Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))

evaluation = reseauNeurones4Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])

historique_apprentissage = reseauNeurones4Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurones4Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8140 - loss: 0.5443 - val_accuracy: 0.8581 - val_loss: 0.4012
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8774 - loss: 0.3506 - val_accuracy: 0.8838 - val_loss: 0.3338
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8899 - loss: 0.3116 - val_accuracy: 0.8928 - val_loss: 0.3043
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8997 - loss: 0.2812 - val_accuracy: 0.9009 - val_loss: 0.2864
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9044 - loss: 0.2654 - val_accuracy: 0.9070 - val_loss: 0.2712
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9106 - loss: 0.2508 - val_accuracy: 0.9062 - val_loss: 0.2688
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9142 - loss: 0.2348 - val_accuracy: 0.9064 - val_loss: 0.2644
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9215 - loss: 0.2198 - val_accuracy: 0.9085 - val_loss: 0.2550
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9248 - loss: 0.2080 - val_accuracy: 0.9072 - val_loss: 0.2574
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9279 - loss: 0.2005 - val_accuracy: 0.9140 - val_loss: 0.2418
# Erreur: 0.2321557104587555
# Précision: 0.9190000295639038
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8294 - loss: 0.4607 - val_accuracy: 0.8453 - val_loss: 0.4206
# Epoch 2/50
#   1/187 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8633 - loss: 0.4209
# /home/vscode/.local/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8633 - loss: 0.4209 - val_accuracy: 0.8459 - val_loss: 0.4178
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8467 - loss: 0.4119 - val_accuracy: 0.8573 - val_loss: 0.3857
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8633 - loss: 0.3725 - val_accuracy: 0.8596 - val_loss: 0.3855
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8587 - loss: 0.3867 - val_accuracy: 0.8646 - val_loss: 0.3698
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8789 - loss: 0.3516 - val_accuracy: 0.8592 - val_loss: 0.3796
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8629 - loss: 0.3768 - val_accuracy: 0.8627 - val_loss: 0.3678
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8867 - loss: 0.2490 - val_accuracy: 0.8621 - val_loss: 0.3725
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8665 - loss: 0.3635 - val_accuracy: 0.8685 - val_loss: 0.3505
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8984 - loss: 0.2977 - val_accuracy: 0.8708 - val_loss: 0.3505
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8696 - loss: 0.3510 - val_accuracy: 0.8719 - val_loss: 0.3478
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9258 - loss: 0.2319 - val_accuracy: 0.8725 - val_loss: 0.3501
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8751 - loss: 0.3413 - val_accuracy: 0.8742 - val_loss: 0.3372
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8750 - loss: 0.3982 - val_accuracy: 0.8704 - val_loss: 0.3437
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8755 - loss: 0.3370 - val_accuracy: 0.8758 - val_loss: 0.3336
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8789 - loss: 0.2913 - val_accuracy: 0.8738 - val_loss: 0.3385
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8773 - loss: 0.3307 - val_accuracy: 0.8775 - val_loss: 0.3325
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9141 - loss: 0.2382 - val_accuracy: 0.8793 - val_loss: 0.3312
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8791 - loss: 0.3259 - val_accuracy: 0.8790 - val_loss: 0.3269
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8477 - loss: 0.3697 - val_accuracy: 0.8799 - val_loss: 0.3257
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8808 - loss: 0.3187 - val_accuracy: 0.8823 - val_loss: 0.3148
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8867 - loss: 0.3044 - val_accuracy: 0.8830 - val_loss: 0.3172
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8831 - loss: 0.3159 - val_accuracy: 0.8814 - val_loss: 0.3223
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8789 - loss: 0.3301 - val_accuracy: 0.8810 - val_loss: 0.3171
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8857 - loss: 0.3126 - val_accuracy: 0.8854 - val_loss: 0.3110
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8867 - loss: 0.2988 - val_accuracy: 0.8860 - val_loss: 0.3116
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8879 - loss: 0.3077 - val_accuracy: 0.8810 - val_loss: 0.3262
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8633 - loss: 0.2999 - val_accuracy: 0.8839 - val_loss: 0.3193
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8855 - loss: 0.3057 - val_accuracy: 0.8893 - val_loss: 0.3037
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9102 - loss: 0.2726 - val_accuracy: 0.8938 - val_loss: 0.2949
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8894 - loss: 0.3006 - val_accuracy: 0.8874 - val_loss: 0.3038
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8789 - loss: 0.2967 - val_accuracy: 0.8884 - val_loss: 0.3004
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8871 - loss: 0.3026 - val_accuracy: 0.8924 - val_loss: 0.2979
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8867 - loss: 0.3681 - val_accuracy: 0.8885 - val_loss: 0.2955
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8888 - loss: 0.2971 - val_accuracy: 0.8857 - val_loss: 0.3018
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9102 - loss: 0.2621 - val_accuracy: 0.8882 - val_loss: 0.3018
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8900 - loss: 0.2971 - val_accuracy: 0.8937 - val_loss: 0.2927
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9297 - loss: 0.2427 - val_accuracy: 0.8907 - val_loss: 0.2935
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8904 - loss: 0.2927 - val_accuracy: 0.8929 - val_loss: 0.2955
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9023 - loss: 0.2705 - val_accuracy: 0.8905 - val_loss: 0.2938
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8916 - loss: 0.2899 - val_accuracy: 0.8871 - val_loss: 0.3012
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8672 - loss: 0.3504 - val_accuracy: 0.8939 - val_loss: 0.3020
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8949 - loss: 0.2833 - val_accuracy: 0.8949 - val_loss: 0.2862
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8750 - loss: 0.3437 - val_accuracy: 0.8950 - val_loss: 0.2940
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8915 - loss: 0.2888 - val_accuracy: 0.8887 - val_loss: 0.2996
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8945 - loss: 0.3264 - val_accuracy: 0.8889 - val_loss: 0.3007
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8957 - loss: 0.2826 - val_accuracy: 0.8916 - val_loss: 0.2971
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9297 - loss: 0.1981 - val_accuracy: 0.8897 - val_loss: 0.2961
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8959 - loss: 0.2811 - val_accuracy: 0.8904 - val_loss: 0.2903
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9180 - loss: 0.2455 - val_accuracy: 0.8919 - val_loss: 0.2907
# Erreur : 0.22969651222229004
# Précision: 0.9172000288963318
# Modèle sauvegardé !
# Epoch 1/10
# /home/vscode/.local/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 71ms/step - accuracy: 0.7429 - loss: 0.7445 - val_accuracy: 0.3359 - val_loss: 2.1597
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - accuracy: 0.8426 - loss: 0.4417 - val_accuracy: 0.5637 - val_loss: 1.5405
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - accuracy: 0.8683 - loss: 0.3725 - val_accuracy: 0.7889 - val_loss: 0.6202
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - accuracy: 0.8816 - loss: 0.3304 - val_accuracy: 0.8937 - val_loss: 0.2913
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - accuracy: 0.8926 - loss: 0.3018 - val_accuracy: 0.8861 - val_loss: 0.3035
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - accuracy: 0.8972 - loss: 0.2856 - val_accuracy: 0.9047 - val_loss: 0.2578
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - accuracy: 0.9018 - loss: 0.2731 - val_accuracy: 0.9133 - val_loss: 0.2399
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 13s 71ms/step - accuracy: 0.9078 - loss: 0.2606 - val_accuracy: 0.9074 - val_loss: 0.2566
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - accuracy: 0.9104 - loss: 0.2497 - val_accuracy: 0.9122 - val_loss: 0.2454
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 13s 71ms/step - accuracy: 0.9145 - loss: 0.2391 - val_accuracy: 0.9221 - val_loss: 0.2207
# Erreur: 0.2120952606201172
# Précision: 0.9228000044822693
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - accuracy: 0.8532 - loss: 0.4067 - val_accuracy: 0.8712 - val_loss: 0.3452
# Epoch 2/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9102 - loss: 0.3109 - val_accuracy: 0.8703 - val_loss: 0.3541
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 79ms/step - accuracy: 0.8684 - loss: 0.3637 - val_accuracy: 0.8872 - val_loss: 0.3013
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8945 - loss: 0.3182 - val_accuracy: 0.8876 - val_loss: 0.3051
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - accuracy: 0.8744 - loss: 0.3486 - val_accuracy: 0.8831 - val_loss: 0.3189
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8828 - loss: 0.3043 - val_accuracy: 0.8836 - val_loss: 0.3105
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - accuracy: 0.8802 - loss: 0.3336 - val_accuracy: 0.8933 - val_loss: 0.2855
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.4048 - val_accuracy: 0.8930 - val_loss: 0.2869
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.8814 - loss: 0.3254 - val_accuracy: 0.8882 - val_loss: 0.3071
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8789 - loss: 0.3268 - val_accuracy: 0.8857 - val_loss: 0.3139
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - accuracy: 0.8847 - loss: 0.3206 - val_accuracy: 0.8950 - val_loss: 0.2829
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8789 - loss: 0.3307 - val_accuracy: 0.8979 - val_loss: 0.2780
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - accuracy: 0.8882 - loss: 0.3068 - val_accuracy: 0.8939 - val_loss: 0.2807
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9102 - loss: 0.2675 - val_accuracy: 0.8954 - val_loss: 0.2804
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 78ms/step - accuracy: 0.8917 - loss: 0.3010 - val_accuracy: 0.8973 - val_loss: 0.2732
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9336 - loss: 0.2348 - val_accuracy: 0.9002 - val_loss: 0.2672
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 79ms/step - accuracy: 0.8917 - loss: 0.2996 - val_accuracy: 0.8967 - val_loss: 0.2753
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9062 - loss: 0.2607 - val_accuracy: 0.8948 - val_loss: 0.2795
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.8929 - loss: 0.2942 - val_accuracy: 0.9016 - val_loss: 0.2694
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8867 - loss: 0.3098 - val_accuracy: 0.9004 - val_loss: 0.2646
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.8957 - loss: 0.2904 - val_accuracy: 0.9018 - val_loss: 0.2706
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8672 - loss: 0.3806 - val_accuracy: 0.9027 - val_loss: 0.2677
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.8947 - loss: 0.2872 - val_accuracy: 0.8979 - val_loss: 0.2732
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8438 - loss: 0.3246 - val_accuracy: 0.9054 - val_loss: 0.2592
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.8981 - loss: 0.2830 - val_accuracy: 0.9082 - val_loss: 0.2481
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9023 - loss: 0.2427 - val_accuracy: 0.9057 - val_loss: 0.2555
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.8998 - loss: 0.2767 - val_accuracy: 0.9034 - val_loss: 0.2636
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9141 - loss: 0.2595 - val_accuracy: 0.9023 - val_loss: 0.2614
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.8997 - loss: 0.2754 - val_accuracy: 0.8989 - val_loss: 0.2725
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.3305 - val_accuracy: 0.9037 - val_loss: 0.2650
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9040 - loss: 0.2690 - val_accuracy: 0.9057 - val_loss: 0.2620
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8828 - loss: 0.3594 - val_accuracy: 0.9027 - val_loss: 0.2678
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9005 - loss: 0.2738 - val_accuracy: 0.9106 - val_loss: 0.2452
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.3145 - val_accuracy: 0.9103 - val_loss: 0.2467
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9020 - loss: 0.2671 - val_accuracy: 0.9126 - val_loss: 0.2387
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.2818 - val_accuracy: 0.9124 - val_loss: 0.2357
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9051 - loss: 0.2627 - val_accuracy: 0.9073 - val_loss: 0.2429
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9180 - loss: 0.2303 - val_accuracy: 0.9069 - val_loss: 0.2465
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.9053 - loss: 0.2635 - val_accuracy: 0.9134 - val_loss: 0.2455
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.3348 - val_accuracy: 0.9110 - val_loss: 0.2463
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.9062 - loss: 0.2606 - val_accuracy: 0.9139 - val_loss: 0.2360
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.2765 - val_accuracy: 0.9136 - val_loss: 0.2413
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9082 - loss: 0.2532 - val_accuracy: 0.9120 - val_loss: 0.2409
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9062 - loss: 0.2880 - val_accuracy: 0.9091 - val_loss: 0.2451
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9099 - loss: 0.2514 - val_accuracy: 0.9142 - val_loss: 0.2313
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8906 - loss: 0.3263 - val_accuracy: 0.9181 - val_loss: 0.2265
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9089 - loss: 0.2507 - val_accuracy: 0.9130 - val_loss: 0.2397
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8867 - loss: 0.2920 - val_accuracy: 0.9080 - val_loss: 0.2533
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.9095 - loss: 0.2499 - val_accuracy: 0.9142 - val_loss: 0.2351
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9219 - loss: 0.2330 - val_accuracy: 0.9125 - val_loss: 0.2389
# Erreur : 0.20481494069099426
# Précision: 0.9258999824523926
